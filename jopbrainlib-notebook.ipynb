# %% [markdown]
# # JopBrainLib

# %% [markdown]
# ## Setup and connection
# Make sure Joplin is running and the webclipper is activated!!
# Running this cell will make the auth window popup in Joplin

# %%
# Imports

## Visual aids
from rich import print, inspect # Fancy datastructure printing

## In case you want to analyze anything
import pandas as pd # Swiss army knife
### Do not truncate cell contents
pd.set_option('display.max_colwidth', None)
### Do not truncate nr of columns shown
pd.set_option('display.max_columns', None)
### Do not truncate nr of rows
pd.set_option('display.max_rows', None)

from joppylib import default_settings, JoplinClient
from jopbrainlib.util.datetimes import get_days_in_month
from jopbrainlib.diary import create_diary_day, create_diary_month

### Load and authenticate the Joplin client
joplinclient = JoplinClient(default_settings)

# %% [markdown]
# ***

# %% [markdown]
# ## Diary note creation per month

# %%
# Create all diary notes for a month
## Last created: march 2026

year = 2026
month = 4
# Make sure notebook_title exactly matches your desired notebook title
notebook_title = 'Diary'
# Set to your templates folder or None
template_folder = '/home/jeroen/.config/jopbrainlib/my_templates'

april = create_diary_month(
    joplinclient,
    year,
    month,
    notebook_title,
    template_folder
)

# %% [markdown]
# ***
